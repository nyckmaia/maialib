# %% [markdown]
# # Find Pattern (In development)

# %%
import maialib as ml

# %%
import maialib as ml

score = ml.Score('../test/xml_examples/Beethoven/Symphony_5th_1Mov.xml')

melodyPattern = [ml.Note("C4", ml.RhythmFigure.QUARTER),
                 ml.Note("D4", ml.RhythmFigure.QUARTER),
                 ml.Note("E4", ml.RhythmFigure.QUARTER)
                ]
df = score.findMelodyPattern(melodyPattern)
df
